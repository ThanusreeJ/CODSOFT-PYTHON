# %%
import json

# Initialize an empty task_list
task_list = []

# Function to add a task to the task_list
def add_task(task_description):
    task_list.append({"task": task_description, "completed": False})

# Function to mark a task as completed in the task_list
def complete_task(task_index):
    if 0 <= task_index < len(task_list):
        task_list[task_index]["completed"] = True
    else:
        print("Invalid task index")

# Function to remove a task from the task_list
def remove_task(task_index):
    if 0 <= task_index < len(task_list):
        del task_list[task_index]
    else:
        print("Invalid task index")

# Function to display the task_list
def display_tasks():
    for index, task in enumerate(task_list):
        status = "✓" if task["completed"] else " "
        print(f"{index}: [{status}] {task['task']}")

# Function to save the task_list to a file
def save_to_file(filename):
    with open(filename, "w") as file:
        json.dump(task_list, file)

# Function to load the task_list from a file
def load_from_file(filename):
    global task_list
    try:
        with open(filename, "r") as file:
            task_list = json.load(file)
    except FileNotFoundError:
        task_list = []

# Main loop
if __name__ == "__main__":
    filename = "task_list.json"
    load_from_file(filename)

    while True:
        print("\nTask List:")
        display_tasks()

        print("\nOptions:")
        print("1. Add Task")
        print("2. Complete Task")
        print("3. Remove Task")
        print("4. Save and Quit")
        choice = input("Enter your choice (1/2/3/4): ")

        if choice == "1":
            task_description = input("Enter the task description: ")
            add_task(task_description)
        elif choice == "2":
            task_index = int(input("Enter the task index to mark as completed: "))
            complete_task(task_index)
        elif choice == "3":
            task_index = int(input("Enter the task index to remove: "))
            remove_task(task_index)
        elif choice == "4":
            save_to_file(filename)
            print("Task List saved. Quitting.")
            break
        else:
            print("Invalid choice. Please choose a valid option.")
# Out:
# Task List:
#
# Options:
# 1. Add Task
# 2. Complete Task
# 3. Remove Task
# 4. Save and Quit
# Enter your choice (1/2/3/4): 1
# Enter the task description: SUM
#
# Task List:
# 0: [ ] SUM
#
# Options:
# 1. Add Task
# 2. Complete Task
# 3. Remove Task
# 4. Save and Quit
# Enter your choice (1/2/3/4): 2
# Enter the task index to mark as completed: 0
#
# Task List:
# 0: [✓] SUM
#
# Options:
# 1. Add Task
# 2. Complete Task
# 3. Remove Task
# 4. Save and Quit
# Enter your choice (1/2/3/4): 3
# Enter the task index to remove: 0
#
# Task List:
#
# Options:
# 1. Add Task
# 2. Complete Task
# 3. Remove Task
# 4. Save and Quit
# Enter your choice (1/2/3/4): 4
# Task List saved. Quitting.
